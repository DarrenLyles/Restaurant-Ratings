# %% [markdown]
# ## San Francisco Restaurant Reviews Natural Language Processing Stage
# ### Darren Lyles

# %% [markdown]
# <p>In the following notebook, we will use natural langage processing funamentals to clean up the reviews and add new features to the data set. Ultimately we will clean up the reviews by tokenizing them and adding a new column. We will then do some EDA to get a better understanding of the dataset features.</p>

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_restaurant_reviews = pd.read_csv('restaurant_reviews.csv', index_col=0)
df_restaurant_reviews.head()
# Out:
#                                   name  \
# 0  21st Amendment Brewery & Restaurant
# 1  21st Amendment Brewery & Restaurant
# 2  21st Amendment Brewery & Restaurant
# 3  21st Amendment Brewery & Restaurant
# 4  21st Amendment Brewery & Restaurant
#
#                                              cuisine     address  \
# 0  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 1  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 2  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 3  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 4  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
#
#         locality region                                              hours  \
# 0  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 1  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 2  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 3  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 4  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
#
#                         email             tel             fax  \
# 0  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 1  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 2  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 3  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 4  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
#
#                                     trip_advisor_url  \
# 0  http://www.tripadvisor.com/Restaurant_Review-g...
# 1  http://www.tripadvisor.com/Restaurant_Review-g...
# 2  http://www.tripadvisor.com/Restaurant_Review-g...
# 3  http://www.tripadvisor.com/Restaurant_Review-g...
# 4  http://www.tripadvisor.com/Restaurant_Review-g...
#
#                          website   latitude   longitude  price  rating  \
# 0  http://www.21st-amendment.com  37.782448 -122.392576      2     4.0
# 1  http://www.21st-amendment.com  37.782448 -122.392576      2     4.0
# 2  http://www.21st-amendment.com  37.782448 -122.392576      2     4.0
# 3  http://www.21st-amendment.com  37.782448 -122.392576      2     4.0
# 4  http://www.21st-amendment.com  37.782448 -122.392576      2     4.0
#
#                                           review_url  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g6...
# 1  https://www.tripadvisor.com/ShowUserReviews-g6...
# 2  https://www.tripadvisor.com/ShowUserReviews-g6...
# 3  https://www.tripadvisor.com/ShowUserReviews-g6...
# 4  https://www.tripadvisor.com/ShowUserReviews-g6...
#
#                                  review_title  \
# 0                       Great drinks and food
# 1                        Good food &amp; beer
# 2                           Pretty good beers
# 3  Ridiculously overpriced (yes I live in SF)
# 4                                 Team dinner
#
#                                          review_text  review_rating  \
# 0  They have great local craft beers and probably...              4
# 1  We went to the downtown SF location. The resta...              4
# 2  I just came to this place for drinks with an o...              4
# 3  Mediocre food (not bad, just mediocre, you can...              3
# 4  We headed out for our team dinner to this esta...              4
#
#                 review_date
# 0  Mar 28, 2016 12:00:00 AM
# 1  Mar 27, 2016 12:00:00 AM
# 2  Mar 16, 2016 12:00:00 AM
# 3   Mar 8, 2016 12:00:00 AM
# 4   Mar 1, 2016 12:00:00 AM

# %% [markdown]
# <p>Below, I am applying preprocessing techniques to each review in our dataset.
#    The first step that needs to be done is to set each string review into the lowercase,
#    then I tokenize each review such that each word is an element in a list.
#    The last three steps I took was to filter out stopwords, punctuation, and finally
#    lemmatize each word in each review.
# </p>

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from string import punctuation

#Set all words in each review in the lower case
#df_restaurant_reviews['tokenized_review_text'] = df_restaurant_reviews.review_text.str.lower()
df_restaurant_reviews.insert(loc=18, column='tokenized_review_text', \
                             value=df_restaurant_reviews.review_text.str.lower())

#Tokenize all Restaurant Reviews
df_restaurant_reviews['tokenized_review_text'] = \
df_restaurant_reviews['tokenized_review_text'].apply(lambda x: word_tokenize(x))

#Filter out stopwords
sw = set(stopwords.words('english'))
df_restaurant_reviews['tokenized_review_text'] = \
df_restaurant_reviews['tokenized_review_text'].apply(lambda x: [y for y in x if y not in sw])

#Filter out punctuation
df_restaurant_reviews['tokenized_review_text'] = \
df_restaurant_reviews['tokenized_review_text'].apply(lambda x: [y for y in x if y not in punctuation])

#Lemmatize each word for each review
wordnet_lemmatizer = WordNetLemmatizer()
df_restaurant_reviews['tokenized_review_text'] = \
df_restaurant_reviews['tokenized_review_text'].apply(lambda x: [wordnet_lemmatizer.lemmatize(w) for w in x])

#Filter to only Reviews in the English Language
#from langdetect import detect
#df_restaurant_reviews['review_text'].apply(lambda x: detect(x)) == 'en'

df_restaurant_reviews.to_csv('restaurant_reviews_tokenized.csv')
df_restaurant_reviews.head()
# Out:
#                                   name  \
# 0  21st Amendment Brewery & Restaurant
# 1  21st Amendment Brewery & Restaurant
# 2  21st Amendment Brewery & Restaurant
# 3  21st Amendment Brewery & Restaurant
# 4  21st Amendment Brewery & Restaurant
#
#                                              cuisine     address  \
# 0  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 1  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 2  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 3  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
# 4  ['Cafe', 'Pub Food', 'American', 'Burgers', 'P...  563 2nd St
#
#         locality region                                              hours  \
# 0  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 1  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 2  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 3  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
# 4  San Francisco     CA  {'monday': [['11:30', '23:59']], 'tuesday': [[...
#
#                         email             tel             fax  \
# 0  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 1  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 2  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 3  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
# 4  new-pub@21st-amendment.com  (415) 369-0900  (415) 369-0909
#
#                                     trip_advisor_url  \
# 0  http://www.tripadvisor.com/Restaurant_Review-g...
# 1  http://www.tripadvisor.com/Restaurant_Review-g...
# 2  http://www.tripadvisor.com/Restaurant_Review-g...
# 3  http://www.tripadvisor.com/Restaurant_Review-g...
# 4  http://www.tripadvisor.com/Restaurant_Review-g...
#
#              ...              latitude   longitude  price  rating  \
# 0            ...             37.782448 -122.392576      2     4.0
# 1            ...             37.782448 -122.392576      2     4.0
# 2            ...             37.782448 -122.392576      2     4.0
# 3            ...             37.782448 -122.392576      2     4.0
# 4            ...             37.782448 -122.392576      2     4.0
#
#                                           review_url  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g6...
# 1  https://www.tripadvisor.com/ShowUserReviews-g6...
# 2  https://www.tripadvisor.com/ShowUserReviews-g6...
# 3  https://www.tripadvisor.com/ShowUserReviews-g6...
# 4  https://www.tripadvisor.com/ShowUserReviews-g6...
#
#                                  review_title  \
# 0                       Great drinks and food
# 1                        Good food &amp; beer
# 2                           Pretty good beers
# 3  Ridiculously overpriced (yes I live in SF)
# 4                                 Team dinner
#
#                                          review_text  \
# 0  They have great local craft beers and probably...
# 1  We went to the downtown SF location. The resta...
# 2  I just came to this place for drinks with an o...
# 3  Mediocre food (not bad, just mediocre, you can...
# 4  We headed out for our team dinner to this esta...
#
#                                tokenized_review_text review_rating  \
# 0  [great, local, craft, beer, probably, one, bes...             4
# 1  [went, downtown, sf, location, restaurant, rea...             4
# 2  [came, place, drink, old, colleague, beer, pre...             4
# 3  [mediocre, food, bad, mediocre, find, food, pr...             3
# 4  [headed, team, dinner, establishment, lot, goo...             4
#
#                 review_date
# 0  Mar 28, 2016 12:00:00 AM
# 1  Mar 27, 2016 12:00:00 AM
# 2  Mar 16, 2016 12:00:00 AM
# 3   Mar 8, 2016 12:00:00 AM
# 4   Mar 1, 2016 12:00:00 AM
#
# [5 rows x 21 columns]

# %%
str(df_restaurant_reviews['review_text'][220])
# Out:
# 'They have many branches and maintain good quality. Amber dhara in palo alto lunch thali is authentic. Santana row has a buffet for lunch which is nice. Their dum biryani is baked with a Naan bread on top to keep the hot steam and flavor inside. The San Francisco location has a wonderful brunch menu and seasonal dishes. Expect to eat at least 500 to 700 calories if you eat the bread as it is not a low calorie diet.'

# %% [markdown]
# <p>
#     Now that we have our dataset ready for natural language processing and analysis, let us explore some of the features.
# </p>

# %%
df_restaurant_reviews.describe()
# Out:
#            latitude     longitude         price        rating  review_rating
# count  16500.000000  16500.000000  16500.000000  16500.000000   16500.000000
# mean      37.782760   -122.421066      1.951515      4.000000       4.228242
# std        0.016237      0.021871      0.658816      0.433463       0.966448
# min       37.732046   -122.513899      1.000000      2.500000       1.000000
# 25%       37.768755   -122.430158      2.000000      4.000000       4.000000
# 50%       37.786022   -122.418143      2.000000      4.000000       4.000000
# 75%       37.795132   -122.407559      2.000000      4.000000       5.000000
# max       37.809470   -122.388432      4.000000      5.000000       5.000000

# %%
df_restaurant_reviews.hist('review_rating',bins=50, figsize=(10, 5))
plt.show()

# %% [markdown]
# <p>
#     The review rating distribuion can give us a better understanding on how restaurants in San Francisco are
#     rated. Overall there are more 5 star review ratings than any other ratings.
# </p>

# %%
#Get the values of the review ratings distribution
df_restaurant_reviews.groupby('review_rating').size()
# Out:
# review_rating
# 1     436
# 2     601
# 3    1833
# 4    5521
# 5    8109
# dtype: int64

# %% [markdown]
# <p>
#     As we can see from above, we have a disproportionate amount of 5-star, 4-star, and 3-star reviews compared to 2-star and 1-star reviews. This may cause the machine learning models to classify 5-star, 4-star and 3-star restaurant reviews with better precision. Since the 1-star and 2-star review ratings are much less, the model can possibly have a low precision, consequently lowering the overall accuracy of the model.
# </p>

# %%
#Checking if the sum of all review ratings matches the actual number of reviews
df_restaurant_reviews.groupby('review_rating').size().agg('sum') == len(df_restaurant_reviews['review_text'])
# Out:
# True

# %%
review_length = df_restaurant_reviews['tokenized_review_text'].apply(len)
plt.hist(review_length, bins=50)
plt.xlabel('tokenized_word_count')
plt.ylabel('frequency')
plt.show()

print("MIN:    {}".format(review_length.min()))
print("MAX:    {}".format(review_length.max()))
print("MEAN:   {}".format(round(review_length.mean(), 1)))
print("MEDIAN: {}".format(round(review_length.median(), 1)))
print("STD:    {}".format(round(review_length.std(), 1)))
# Out:
# MIN:    1
# MAX:    583
# MEAN:   41.1
# MEDIAN: 31.0
# STD:    35.5

# %% [markdown]
# <p>
#     The distribution above shows the frequency of tokenized word counts for all reviews. The median tokenized review length is 31 while the mean tokenized word length is 41.1.
# </p>

# %%
reviews_and_ratings = pd.DataFrame()
reviews_and_ratings['review_rating'] = df_restaurant_reviews['review_rating']
reviews_and_ratings['tokenized_review_text_length'] = review_length

figs, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
figs.delaxes(axes.flatten()[5])

reviews_and_ratings_1 = pd.DataFrame(reviews_and_ratings[reviews_and_ratings['review_rating'] == 1])
reviews_and_ratings_1.rename(columns={'tokenized_review_text_length': 
                                      '1_star_tokenized_review_text_length'}, inplace=True)
reviews_and_ratings_1.hist('1_star_tokenized_review_text_length', bins=50, ax=axes[0,0])

reviews_and_ratings_2 = pd.DataFrame(reviews_and_ratings[reviews_and_ratings['review_rating'] == 2])
reviews_and_ratings_2.rename(columns={'tokenized_review_text_length': 
                                      '2_star_tokenized_review_text_length'}, inplace=True)
reviews_and_ratings_2.hist('2_star_tokenized_review_text_length', bins=50, ax=axes[0,1])

reviews_and_ratings_3 = pd.DataFrame(reviews_and_ratings[reviews_and_ratings['review_rating'] == 3])
reviews_and_ratings_3.rename(columns={'tokenized_review_text_length': 
                                      '3_star_tokenized_review_text_length'}, inplace=True)
reviews_and_ratings_3.hist('3_star_tokenized_review_text_length', bins=50, ax=axes[0,2])

reviews_and_ratings_4 = pd.DataFrame(reviews_and_ratings[reviews_and_ratings['review_rating'] == 4])
reviews_and_ratings_4.rename(columns={'tokenized_review_text_length': 
                                      '4_star_tokenized_review_text_length'}, inplace=True)
reviews_and_ratings_4.hist('4_star_tokenized_review_text_length', bins=50, ax=axes[1,0])

reviews_and_ratings_5 = pd.DataFrame(reviews_and_ratings[reviews_and_ratings['review_rating'] == 5])
reviews_and_ratings_5.rename(columns={'tokenized_review_text_length': 
                                      '5_star_tokenized_review_text_length'}, inplace=True)
reviews_and_ratings_5.hist('5_star_tokenized_review_text_length', bins=50, ax=axes[1,1])


plt.show()

reviews_and_ratings.groupby('review_rating').count()
# Out:
#                tokenized_review_text_length
# review_rating
# 1                                       436
# 2                                       601
# 3                                      1833
# 4                                      5521
# 5                                      8109

# %% [markdown]
# <p>
#     The distributions illustrate the relationship between the restaurant reviewer's rating and the review given.
#     Here we have the distribution of the tokenized review text length. We see that there is a significantly higher
#     frequency of highly reveiwed restaurants as opposed to restaurants given a review rating of 1, 2, or 3. The
#     range for the number of tokenized words used across all restaurant ratings is given below.
# </p>

# %%
reviews_and_ratings.groupby('review_rating').apply(lambda x: x.max() - x.min()) \
.drop(columns='review_rating') \
.rename(columns={'tokenized_review_text_length': 'tokenized_review_text_length_range'})
# Out:
#                tokenized_review_text_length_range
# review_rating
# 1                                             575
# 2                                             356
# 3                                             447
# 4                                             453
# 5                                             540

# %%
sns.boxplot(x='review_rating', y='tokenized_review_text_length', data=reviews_and_ratings)
plt.show()

# %%
sns.violinplot(x='review_rating', y='tokenized_review_text_length', data=reviews_and_ratings)
plt.show()

# %% [markdown]
# <p>
#     The box and violin plots above show how the tokenized review lengh differes across each restaurant rating.
# </p>

# %%
g = sns.FacetGrid(data=df_restaurant_reviews, col='price')
g.map(plt.hist, 'review_rating', bins=10)
plt.show()

# %% [markdown]
# <p>
#     The following plots shows the number of ratings with respect to the price. It seems that restaurant reviewers
#     in San Francisco tend to go to restaurants with two dollar signs. Not only that, but two dollar sign
#     restaurants have the highest number of 5 star ratings than any other restaurants. This should not however,
#     imply that the more 5 star restaurant ratings, the better. This is an example of
#     voluntary response bias since not every person rates and reviews a restaurant they visited, and the frequency
#     of restaurant reviewers for each restaurant is not uniform.  This means the number of reviewers for each
#     restaurant is not the same in general.
# </p>
